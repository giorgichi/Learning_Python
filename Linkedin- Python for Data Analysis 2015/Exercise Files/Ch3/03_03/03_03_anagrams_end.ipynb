# %%
word = open('words','r')

# %%
word
# Out:
# <_io.TextIOWrapper name='words' mode='r' encoding='cp1252'>

# %%
wordlist = word.readlines()

# %%
wordlist[:10]
# Out:
# ['A\n',
#  'a\n',
#  'aa\n',
#  'aal\n',
#  'aalii\n',
#  'aam\n',
#  'Aani\n',
#  'aardvark\n',
#  'aardwolf\n',
#  'Aaron\n']

# %%
len(wordlist)
# Out:
# 235886

# %%
'Aaron\n'.strip()
# Out:
# 'Aaron'

# %%
'Aaron'.lower()
# Out:
# 'aaron'

# %%
wordclean = [word.strip().lower() for word in wordlist]

# %%
wordclean[:10]
# Out:
# ['a',
#  'a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron']

# %%
wordunique = list(set(wordclean))

# %%
# wordunique

# %%
wordunique.sort()

# %%
wordunique[:10]
# Out:
# ['a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron',
#  'aaronic']

# %%
wordclean = [word.strip().lower() for word in open('words','r')]

# %%
wordclean[:10]
# Out:
# ['a',
#  'a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron']

# %%
wordclean = sorted(list(set([word.strip().lower() for word in open('words','r')])))

# %%
wordclean[:10]
# Out:
# ['a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron',
#  'aaronic']

# %%
sorted('lives')
# Out:
# ['e', 'i', 'l', 's', 'v']

# %%
sorted('lives') == sorted('elvis')
# Out:
# True

# %%
sorted('love') == sorted('hate')
# Out:
# False

# %%
def signature(word):
    return ''.join(sorted(word))

# %%
signature('lives')
# Out:
# 'eilsv'

# %%
'/'.join(['a','b','c'])
# Out:
# 'a/b/c'

# %%
def anagram(word):
    return [w for w in wordclean if signature(w) == signature(word)]

# %%
anagram('dictionary')
# Out:
# ['dictionary', 'indicatory']

# %%
# %timeit anagram('dictionary')
# Out:
# 815 ms ± 40.8 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
words_bysig = {}

for word in wordclean:
    words_bysig[signature(word)].append(word)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 4
#       1 words_bysig = {}
#       3 for word in wordclean:
# ----> 4     words_bysig[signature(word)].append(word)
#
# KeyError: 'a'

# %%
import collections

# %%
words_bysig = collections.defaultdict(list)

for word in wordclean:
    words_bysig[signature(word)].append(word)

# %%
#words_bysig

# %%
def anagram_fast(word):
    return words_bysig[signature(word)]

# %%
anagram_fast('dictionary')
# Out:
# ['dictionary', 'indicatory']

# %%
anagrams_all = {word: anagram_fast(word) for word in wordclean 
                if len(anagram_fast(word)) > 1}

# %%
len(anagrams_all)
# Out:
# 32890

# %%
# %timeit anagrams_all = {word: anagram_fast(word) for word in wordclean if len(anagram_fast(word)) > 1}
# Out:
# 702 ms ± 33.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

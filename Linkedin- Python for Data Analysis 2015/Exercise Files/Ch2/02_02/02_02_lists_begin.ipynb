# %% [markdown]
# ## List
#
# Python list are useful and ubiquitous becuase:
#
# 1. Flexible and contains **heterogeneous** data
# 2. Use where **order** of elements matter
# 3. or where can be addressed by a numeral
# 4. Use sclicing system to operate on sublists

# %%
newphews = ["Gio", "Ana", "Nika"]

# %%
print(newphews)
# Out:
# ['Gio', 'Ana', 'Nika']

# %%
newphews
# Out:
# ['Gio', 'Ana', 'Nika']

# %%
newphews[0]
# Out:
# 'Gio'

# %%
newphews.reverse()

# %%
newphews
# Out:
# ['Nika', 'Ana', 'Gio']

# %%
len(newphews)
# Out:
# 3

# %%
mix_it_up = ["gio", [1, 2], 1.5]

# %%
mix_it_up[1]
# Out:
# [1, 2]

# %%
newphews.append("Kaki")

# %%
newphews
# Out:
# ['Nika', 'Ana', 'Gio', 'Kaki']

# %%
newphews.extend(["David", "Zura", "Guram"])

# %%
newphews
# Out:
# ['Nika', 'Ana', 'Gio', 'Kaki', 'David', 'Zura', 'Guram']

# %%
newphews.insert(1, "Zaza")

# %%
newphews
# Out:
# ['Nika', 'Zaza', 'Ana', 'Gio', 'Kaki', 'David', 'Zura', 'Guram']

# %%
del newphews[1]

# %%
newphews
# Out:
# ['Nika', 'Ana', 'Gio', 'Kaki', 'David', 'Zura', 'Guram']

# %%
newphews.remove("David")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 newphews.remove("David")
#
# ValueError: list.remove(x): x not in list

# %%
newphews
# Out:
# ['Nika', 'Ana', 'Gio', 'Kaki', 'Zura', 'Guram']

# %%
newphews.sort()
newphews
# Out:
# ['Ana', 'Gio', 'Guram', 'Kaki', 'Nika', 'Zura']

# %%
squares = [0, 1, 4, 16,25,36,49]

# %%
squares
# Out:
# [0, 1, 4, 16, 25, 36, 49]

# %%
squares[0:2]
# Out:
# [0, 1]

# %%
squares[:5]
# Out:
# [0, 1, 4, 16, 25]

# %%
squares[-1]
# Out:
# 49

# %%
squares[2:4] = [9, 4]

# %%
squares
# Out:
# [0, 1, 9, 4, 25, 36, 49]

# %%
for value in newphews:
    print("My name is", value)
# Out:
# My name is Ana
# My name is Gio
# My name is Guram
# My name is Kaki
# My name is Nika
# My name is Zura

# %%
for index, value in enumerate(squares):
    print("Element #", index, "->", value)
# Out:
# Element # 0 -> 0
# Element # 1 -> 1
# Element # 2 -> 9
# Element # 3 -> 4
# Element # 4 -> 25
# Element # 5 -> 36
# Element # 6 -> 49

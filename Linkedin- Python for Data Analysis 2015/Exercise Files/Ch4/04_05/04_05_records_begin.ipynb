# %%
import numpy as np

# %%
reca = np.array([(1, (2.0, 3.0), 'hey'), (2, (3.5, 4.0), 'n')],
               dtype=[('x', np.int32), ('y', np.float64, 2), ('z', 'U4')])
reca
# Out:
# array([(1, [2. , 3. ], 'hey'), (2, [3.5, 4. ], 'n')],
#       dtype=[('x', '<i4'), ('y', '<f8', (2,)), ('z', '<U4')])

# %%
reca[0]
# Out:
# np.void((1, [2.0, 3.0], 'hey'), dtype=[('x', '<i4'), ('y', '<f8', (2,)), ('z', '<U4')])

# %%
reca['x']
# Out:
# array([1, 2], dtype=int32)

# %%
reca['z']
# Out:
# array(['hey', 'n'], dtype='<U4')

# %%
np.datetime64('2022')
# Out:
# np.datetime64('2022')

# %%
np.datetime64('2022-06')
# Out:
# np.datetime64('2022-06')

# %%
np.datetime64('2022-06-25')
# Out:
# np.datetime64('2022-06-25')

# %%
np.datetime64('2022-06-25 11:00:00+0700')
# Out:
# C:\Users\gio\AppData\Local\Temp\ipykernel_13028\3542441385.py:1: UserWarning: no explicit representation of timezones available for np.datetime64
#   np.datetime64('2022-06-25 11:00:00+0700')
# np.datetime64('2022-06-25T04:00:00')

# %%
np.datetime64('2025-01-12') + np.timedelta64(5,'D')
# Out:
# np.datetime64('2025-01-17')

# %%
np.datetime64('2015-01-01') + np.timedelta64(5,'h')
# Out:
# np.datetime64('2015-01-01T05','h')

# %%
np.datetime64('2015-01-01') + np.timedelta64(5,'h') + np.timedelta64(12,'m')
# Out:
# np.datetime64('2015-01-01T05:12')

# %%
mydate  = np.datetime64('2015-01-01') + np.timedelta64(5,'h') + np.timedelta64(12,'m') + np.timedelta64(55,'s')
mydate
# Out:
# np.datetime64('2015-01-01T05:12:55')

# %%
print(mydate)
# Out:
# 2015-01-01T05:12:55

# %%
mydate.astype(float)
# Out:
# np.float64(1420089175.0)

# %%
mydate.astype(int)
# Out:
# np.int64(1420089175)

# %%
np.datetime64('1970-01-01').astype(float)
# Out:
# np.float64(0.0)

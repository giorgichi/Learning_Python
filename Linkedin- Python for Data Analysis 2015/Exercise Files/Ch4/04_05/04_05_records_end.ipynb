# %%
import numpy as np

# %%
reca = np.array(
    [(1, (2.0, 3.0), 'hey'), (2, (3.5, 4.0), 'n')],
    dtype=[('num', np.int32), ('range', np.float64, 2), ('letter', 'U4')]
)

# %%
reca
# Out:
# array([(1, [2. , 3. ], 'hey'), (2, [3.5, 4. ], 'n')],
#       dtype=[('num', '<i4'), ('range', '<f8', (2,)), ('letter', '<U4')])

# %%
reca[0]
# Out:
# np.void((1, [2.0, 3.0], 'hey'), dtype=[('num', '<i4'), ('range', '<f8', (2,)), ('letter', '<U4')])

# %%
reca['num']
# Out:
# array([1, 2], dtype=int32)

# %%
reca['num'][0]
# Out:
# np.int32(1)

# %%
reca[0]['num']
# Out:
# np.int32(1)

# %%
np.datetime64('2015')
# Out:
# np.datetime64('2015')

# %%
np.datetime64('2015-01')
# Out:
# np.datetime64('2015-01')

# %%
np.datetime64('2015-02-03 12:00:00')
# Out:
# np.datetime64('2015-02-03T12:00:00')

# %%
np.datetime64('2015-02-03 12:00:00+0700')
# Out:
# C:\Users\gio\AppData\Local\Temp\ipykernel_33580\3475597522.py:1: UserWarning: no explicit representation of timezones available for np.datetime64
#   np.datetime64('2015-02-03 12:00:00+0700')
# np.datetime64('2015-02-03T05:00:00')

# %%
np.datetime64('2015-01-01') < np.datetime64('2015-04-03')
# Out:
# np.True_

# %%
np.datetime64('2015-04-03') - np.datetime64('2015-01-01')
# Out:
# np.timedelta64(92,'D')

# %%
np.datetime64('2026-07-30') - np.datetime64('2026')
# Out:
# np.timedelta64(210,'D')

# %%
np.datetime64('2025-01-12') + np.timedelta64(5,'D')
# Out:
# np.datetime64('2025-01-17')

# %%
np.datetime64('2015-01-01') + np.timedelta64(5,'h')
# Out:
# np.datetime64('2015-01-01T05','h')

# %%
np.datetime64('2015-01-01').astype(float)
# Out:
# np.float64(16436.0)

# %%
np.datetime64('1970-01-01').astype(float)
# Out:
# np.float64(0.0)

# %%
r = np.arange(np.datetime64('2026-02-01'),np.datetime64('2026-03-01'))

# %%
r
# Out:
# array(['2026-02-01', '2026-02-02', '2026-02-03', '2026-02-04',
#        '2026-02-05', '2026-02-06', '2026-02-07', '2026-02-08',
#        '2026-02-09', '2026-02-10', '2026-02-11', '2026-02-12',
#        '2026-02-13', '2026-02-14', '2026-02-15', '2026-02-16',
#        '2026-02-17', '2026-02-18', '2026-02-19', '2026-02-20',
#        '2026-02-21', '2026-02-22', '2026-02-23', '2026-02-24',
#        '2026-02-25', '2026-02-26', '2026-02-27', '2026-02-28'],
#       dtype='datetime64[D]')

# %%
import numpy as np
v = np.linspace(0,12,5)
v
# Out:
# array([ 0.,  3.,  6.,  9., 12.])

# %%
v[0]
# Out:
# np.float64(0.0)

# %%
v[1]
# Out:
# np.float64(3.0)

# %%
v[-1]
# Out:
# np.float64(12.0)

# %%
vv = np.random.randn(5, 4)
vv
# Out:
# array([[ 1.17033791,  0.15960431,  0.21822688,  1.22222122],
#        [-0.0245057 , -0.39704938, -0.64103562, -0.58246975],
#        [-1.59206976,  0.08634082,  0.85013878, -1.82575132],
#        [-0.14616271,  0.97407437,  1.30233228, -0.2139532 ],
#        [ 0.44096846, -0.10120841, -0.39194206, -0.79370517]])

# %%
vv[0,0]
# Out:
# np.float64(1.1703379145476176)

# %%
vv[1,3]
# Out:
# np.float64(-0.5824697453950217)

# %%
vv[3,1]
# Out:
# np.float64(0.9740743699577324)

# %%
ll = [[1,2,3], [4,5,6], [7,8,9]]
ll
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
ll[1]
# Out:
# [4, 5, 6]

# %%
ll[1][2]
# Out:
# 6

# %%
v[2:4]
# Out:
# array([6., 9.])

# %%
vv[2:5, 1]
# Out:
# array([ 0.08634082,  0.97407437, -0.10120841])

# %%
vv[2:5, 1:2]
# Out:
# array([[ 0.08634082],
#        [ 0.97407437],
#        [-0.10120841]])

# %%
vv[0:-2, :]
# Out:
# array([[ 1.17033791,  0.15960431,  0.21822688,  1.22222122],
#        [-0.0245057 , -0.39704938, -0.64103562, -0.58246975],
#        [-1.59206976,  0.08634082,  0.85013878, -1.82575132]])

# %%
# every other element 
vv[:, ::2]
# Out:
# array([[ 1.17033791,  0.21822688],
#        [-0.0245057 , -0.64103562],
#        [-1.59206976,  0.85013878],
#        [-0.14616271,  1.30233228],
#        [ 0.44096846, -0.39194206]])

# %%
v2 = v[2:4]
v2
# Out:
# array([6., 9.])

# %%
v2[0] = 0
v2
# Out:
# array([0., 9.])

# %%
v
# Out:
# array([ 0.,  3.,  0.,  9., 12.])

# %%
v3 = v[2:4].copy().transpose()
v3
# Out:
# array([0., 9.])

# %%
v3 = v[2:4].copy()
v3
# Out:
# array([0., 9.])

# %%
v3
# Out:
# array([0., 9.])

# %%
v3[0] = 2
v3
# Out:
# array([2., 9.])

# %%
v
# Out:
# array([ 0.,  3.,  0.,  9., 12.])

# %%
v[[1,2,3,]]
# Out:
# array([3., 0., 9.])

# %%
bool_index = v > 0
bool_index
# Out:
# array([False,  True, False,  True,  True])

# %%
v[bool_index]
# Out:
# array([ 3.,  9., 12.])

# %%
vv[vv > 0.5] = vv[vv > 0.5] * 2

# %%
vv
# Out:
# array([[ 2.34067583,  0.15960431,  0.21822688,  2.44444244],
#        [-0.0245057 , -0.39704938, -0.64103562, -0.58246975],
#        [-1.59206976,  0.08634082,  1.70027755, -1.82575132],
#        [-0.14616271,  1.94814874,  2.60466455, -0.2139532 ],
#        [ 0.44096846, -0.10120841, -0.39194206, -0.79370517]])

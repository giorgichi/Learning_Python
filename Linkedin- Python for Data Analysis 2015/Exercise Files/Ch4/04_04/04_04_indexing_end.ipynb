# %%
import numpy as np

# %%
v = np.linspace(0,10,5)
v
# Out:
# array([ 0. ,  2.5,  5. ,  7.5, 10. ])

# %%
v[0]
# Out:
# np.float64(0.0)

# %%
v[1]
# Out:
# np.float64(2.5)

# %%
v[-1]
# Out:
# np.float64(10.0)

# %%
v[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 v[5]
#
# IndexError: index 5 is out of bounds for axis 0 with size 5

# %%
vv = np.random.random((5,4))

# %%
vv
# Out:
# array([[0.55284618, 0.78595129, 0.05357769, 0.67866713],
#        [0.37397335, 0.96309807, 0.12908455, 0.50197633],
#        [0.94101534, 0.66732567, 0.68439828, 0.39422646],
#        [0.86659719, 0.68134372, 0.52723646, 0.92093861],
#        [0.48141535, 0.81196269, 0.45354062, 0.50369212]])

# %%
vv[0,0]
# Out:
# np.float64(0.5528461755956868)

# %%
vv[4,3]
# Out:
# np.float64(0.5036921249574401)

# %%
ll = [[1,2,3],[4,5,6],[7,8,9]]

# %%
ll[1,2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 ll[1,2]
#
# TypeError: list indices must be integers or slices, not tuple

# %%
ll[1][2]
# Out:
# 6

# %%
v[2:4]
# Out:
# array([5. , 7.5])

# %%
vv[2:5,1]
# Out:
# array([0.66732567, 0.68134372, 0.81196269])

# %%
vv[2:5,1:2]
# Out:
# array([[0.66732567],
#        [0.68134372],
#        [0.81196269]])

# %%
vv[2:-1,:]
# Out:
# array([[0.94101534, 0.66732567, 0.68439828, 0.39422646],
#        [0.86659719, 0.68134372, 0.52723646, 0.92093861]])

# %%
vv[:,::2]
# Out:
# array([[0.55284618, 0.05357769],
#        [0.37397335, 0.12908455],
#        [0.94101534, 0.68439828],
#        [0.86659719, 0.52723646],
#        [0.48141535, 0.45354062]])

# %%
v2 = v[2:4]
v2
# Out:
# array([5. , 7.5])

# %%
v2[0] = 0

# %%
v
# Out:
# array([ 0. ,  2.5,  0. ,  7.5, 10. ])

# %%
v3 = v[2:4].copy()

# %%
v3[0] = 1

# %%
v
# Out:
# array([ 0. ,  2.5,  0. ,  7.5, 10. ])

# %%
v[[1,2,3]]
# Out:
# array([2.5, 0. , 7.5])

# %%
bool_index = v > 0
bool_index
# Out:
# array([False,  True, False,  True,  True])

# %%
v[bool_index]
# Out:
# array([ 2.5,  7.5, 10. ])

# %%
vv[vv > 0.5] = vv[vv > 0.5] * 2

# %%
vv
# Out:
# array([[1.10569235, 1.57190257, 0.05357769, 1.35733427],
#        [0.37397335, 1.92619614, 0.12908455, 1.00395266],
#        [1.88203068, 1.33465133, 1.36879656, 0.39422646],
#        [1.73319439, 1.36268744, 1.05447293, 1.84187722],
#        [0.48141535, 1.62392537, 0.45354062, 1.00738425]])
